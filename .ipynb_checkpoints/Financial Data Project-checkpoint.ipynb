# %%
import pandas_datareader.data as wb

import pandas as pd
import numpy as np
import datetime
# %matplotlib inline

# %%
df=pd.read_pickle('resources/all_banks')

# %%
df.head(2)
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info    Open   High    Low  Close    Volume   Open   High    Low  Close
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.0  493.8  481.1  492.9
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.6  491.0  483.5  483.8
#
# Bank Ticker           ...     MS                                 WFC         \
# Stock Info    Volume  ...   Open   High    Low  Close   Volume  Open   High
# Date                  ...
# 2006-01-03   1537660  ...  57.17  58.49  56.74  58.31  5377000  31.6  31.98
# 2006-01-04   1871020  ...  58.70  59.28  58.35  58.35  7977800  31.8  31.82
#
# Bank Ticker
# Stock Info     Low  Close    Volume
# Date
# 2006-01-03   31.20  31.90  11016400
# 2006-01-04   31.36  31.53  10871000
#
# [2 rows x 30 columns]

# %%
len(df)
# Out:
# 2517

# %%
tickers =[]
for one,two in df.columns.unique():
    if one in tickers:
        continue
    else:
        tickers.append(one)
tickers
# Out:
# ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %%
df.xs('2006-01-03').head(1)
# Out:
# Bank Ticker  Stock Info
# BAC          Open          46.92
# Name: 2006-01-03 00:00:00, dtype: float64

# %%
for i in tickers:
    print(df.xs(i,axis=1).max())
# Out:
# Stock Info
# Open      5.504000e+01
# High      5.508000e+01
# Low       5.482000e+01
# Close     5.490000e+01
# Volume    1.226791e+09
# dtype: float64
# Stock Info
# Open            566.0
# High            570.0
# Low             555.5
# Close           564.1
# Volume    513178690.0
# dtype: float64
# Stock Info
# Open      2.435500e+02
# High      2.507000e+02
# Low       2.400000e+02
# Close     2.479200e+02
# Volume    1.145906e+08
# dtype: float64
# Stock Info
# Open      7.019000e+01
# High      7.061000e+01
# Low       6.946000e+01
# Close     7.008000e+01
# Volume    2.172942e+08
# dtype: float64
# Stock Info
# Open      9.077000e+01
# High      9.095000e+01
# Low       8.833000e+01
# Close     8.930000e+01
# Volume    3.297860e+08
# dtype: float64
# Stock Info
# Open      5.873000e+01
# High      5.876000e+01
# Low       5.807000e+01
# Close     5.852000e+01
# Volume    4.787366e+08
# dtype: float64

# %%
df.xs(tickers,axis=1).max()
# Out:
# Bank Ticker  Stock Info
# BAC          Open          5.504000e+01
#              High          5.508000e+01
#              Low           5.482000e+01
#              Close         5.490000e+01
#              Volume        1.226791e+09
# C            Open          5.660000e+02
#              High          5.700000e+02
#              Low           5.555000e+02
#              Close         5.641000e+02
#              Volume        5.131787e+08
# GS           Open          2.435500e+02
#              High          2.507000e+02
#              Low           2.400000e+02
#              Close         2.479200e+02
#              Volume        1.145906e+08
# JPM          Open          7.019000e+01
#              High          7.061000e+01
#              Low           6.946000e+01
#              Close         7.008000e+01
#              Volume        2.172942e+08
# MS           Open          9.077000e+01
#              High          9.095000e+01
#              Low           8.833000e+01
# ...

# %%
df.xs(('BAC','Close'),axis=1).max()
# Out:
# 54.9

# %%
for i in tickers:
    n = str(df.xs((i,'Close'),axis=1).max())
    print(i+' '+n)
# Out:
# BAC 54.9
# C 564.1
# GS 247.92
# JPM 70.08
# MS 89.3
# WFC 58.52

# %%
dff = df.xs(tickers,axis=1).max()

# %%
df[('BAC','Close')]
# Out:
# Date
# 2006-01-03    47.08
# 2006-01-04    46.58
# 2006-01-05    46.64
# 2006-01-06    46.57
# 2006-01-09    46.60
#               ...
# 2015-12-24    17.27
# 2015-12-28    17.13
# 2015-12-29    17.28
# 2015-12-30    17.05
# 2015-12-31    16.83
# Name: (BAC, Close), Length: 2517, dtype: float64

# %%
#df.xs((tickers,'Close'),axis=1)

# %%
df.xs(('BAC','Close'),level=[0,'Stock Info'],axis=1).max()
# Out:
# Bank Ticker  Stock Info
# BAC          Close         54.9
# dtype: float64

# %%
df[tickers].xs(('BAC','Close'),level=[0,'Stock Info'],axis=1).max()
# Out:
# Bank Ticker  Stock Info
# BAC          Close         54.9
# dtype: float64

# %%
df[tickers[3]].max()
# Out:
# Stock Info
# Open      7.019000e+01
# High      7.061000e+01
# Low       6.946000e+01
# Close     7.008000e+01
# Volume    2.172942e+08
# dtype: float64

# %%
df[3:4]
# Out:
# Bank Ticker   BAC                                     C                       \
# Stock Info   Open   High    Low  Close    Volume   Open   High    Low  Close
# Date
# 2006-01-06   46.8  46.91  46.35  46.57  12599800  488.8  489.0  482.0  486.2
#
# Bank Ticker           ...     MS                                  WFC         \
# Stock Info    Volume  ...   Open   High    Low  Close   Volume   Open   High
# Date                  ...
# 2006-01-06   1370250  ...  58.77  58.85  58.05  58.57  6889800  31.58  31.78
#
# Bank Ticker
# Stock Info     Low  Close   Volume
# Date
# 2006-01-06   31.38  31.68  8403800
#
# [1 rows x 30 columns]

# %%
df.xs(('BAC','Close'),axis=1).max()
# Out:
# 54.9

# %%
df.xs(('BAC',"Close"),axis=1)
# Out:
# Date
# 2006-01-03    47.08
# 2006-01-04    46.58
# 2006-01-05    46.64
# 2006-01-06    46.57
# 2006-01-09    46.60
#               ...
# 2015-12-24    17.27
# 2015-12-28    17.13
# 2015-12-29    17.28
# 2015-12-30    17.05
# 2015-12-31    16.83
# Name: (BAC, Close), Length: 2517, dtype: float64

# %%
df.xs('Close',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.90
# C      564.10
# GS     247.92
# JPM     70.08
# MS      89.30
# WFC     58.52
# dtype: float64

# %%
col = ['BAC Return','C Return','GS Return','JPM Return','MS Return','WFC Return']
returns = pd.DataFrame(columns = col)

# %%
returns
# Out:
# Empty DataFrame
# Columns: [BAC Return, C Return, GS Return, JPM Return, MS Return, WFC Return]
# Index: []

# %%
returns.index
# Out:
# Index([], dtype='object')

# %%
df['BAC Return'] = df[]
# Out:
# Series([], Name: BAC Return, dtype: object)

# %%
df['BAC']
# Out:
# Stock Info   Open   High    Low  Close    Volume
# Date
# 2006-01-03  46.92  47.18  46.15  47.08  16296700
# 2006-01-04  47.00  47.24  46.45  46.58  17757900
# 2006-01-05  46.58  46.83  46.32  46.64  14970900
# 2006-01-06  46.80  46.91  46.35  46.57  12599800
# 2006-01-09  46.72  46.97  46.36  46.60  15620000
# ...           ...    ...    ...    ...       ...
# 2015-12-24  17.32  17.38  17.22  17.27  29373415
# 2015-12-28  17.22  17.23  16.98  17.13  41777497
# 2015-12-29  17.25  17.35  17.16  17.28  45670376
# 2015-12-30  17.20  17.24  17.04  17.05  35066378
# 2015-12-31  17.01  17.07  16.83  16.83  47152968
#
# [2517 rows x 5 columns]

# %%
df['BAC Return'] = df["BAC"]['Close'].pct_change()

# %%
df["BAC"][['Close','Open']]
# Out:
# Stock Info  Close   Open
# Date
# 2006-01-03  47.08  46.92
# 2006-01-04  46.58  47.00
# 2006-01-05  46.64  46.58
# 2006-01-06  46.57  46.80
# 2006-01-09  46.60  46.72
# ...           ...    ...
# 2015-12-24  17.27  17.32
# 2015-12-28  17.13  17.22
# 2015-12-29  17.28  17.25
# 2015-12-30  17.05  17.20
# 2015-12-31  16.83  17.01
#
# [2517 rows x 2 columns]

# %%
df['BAC']['Close'].pct_change()
# Out:
# Date
# 2006-01-03         NaN
# 2006-01-04   -0.010620
# 2006-01-05    0.001288
# 2006-01-06   -0.001501
# 2006-01-09    0.000644
#                 ...
# 2015-12-24   -0.004037
# 2015-12-28   -0.008107
# 2015-12-29    0.008757
# 2015-12-30   -0.013310
# 2015-12-31   -0.012903
# Name: Close, Length: 2517, dtype: float64

# %%
returns['BAC Return'] = df['BAC']['Close'].pct_change()

# %%
# Out:
#             BAC Return C Return GS Return JPM Return MS Return WFC Return
# Date
# 2006-01-03         NaN      NaN       NaN        NaN       NaN        NaN
# 2006-01-04   -0.010620      NaN       NaN        NaN       NaN        NaN
# 2006-01-05    0.001288      NaN       NaN        NaN       NaN        NaN
# 2006-01-06   -0.001501      NaN       NaN        NaN       NaN        NaN
# 2006-01-09    0.000644      NaN       NaN        NaN       NaN        NaN
# ...                ...      ...       ...        ...       ...        ...
# 2015-12-24   -0.004037      NaN       NaN        NaN       NaN        NaN
# 2015-12-28   -0.008107      NaN       NaN        NaN       NaN        NaN
# 2015-12-29    0.008757      NaN       NaN        NaN       NaN        NaN
# 2015-12-30   -0.013310      NaN       NaN        NaN       NaN        NaN
# 2015-12-31   -0.012903      NaN       NaN        NaN       NaN        NaN
#
# [2517 rows x 6 columns]

# %%
returns.columns
# Out:
# Index(['BAC Return', 'C Return', 'GS Return', 'JPM Return', 'MS Return',
#        'WFC Return'],
#       dtype='object')

# %%
tickers
# Out:
# ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %%
x = 0
for c in returns.columns:
    returns[c] = df[tickers[x]]['Close'].pct_change()
    x+=1

# %%
returns
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.000951
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005714
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586    0.000000
# ...                ...       ...        ...         ...        ...         ...
# 2015-12-24   -0.004037  0.001520  -0.002624   -0.001948  -0.003681   -0.003997
# 2015-12-28   -0.008107 -0.006261  -0.004658   -0.003303  -0.009544   -0.002554
# 2015-12-29    0.008757  0.011455   0.010516    0.010395   0.011812    0.011156
# 2015-12-30   -0.013310 -0.012835  -0.008282   -0.007157  -0.009831   -0.007235
# 2015-12-31   -0.012903 -0.010516  -0.009780   -0.008410  -0.013031   -0.009656
#
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(returns)

# %%
returns[['BAC Return']].idxmax()
# Out:
# BAC Return   2009-04-09
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# BAC Return   2009-04-09
# C Return     2011-05-09
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %%
returns.idxmin()
# Out:
# BAC Return   2009-01-20
# C Return     2011-05-06
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %%
returns.std()
# Out:
# BAC Return    0.036650
# C Return      0.179969
# GS Return     0.025346
# JPM Return    0.027656
# MS Return     0.037820
# WFC Return    0.030233
# dtype: float64

# %%
returns.loc['2015-01-01':'2015-12-31'].std()
# Out:
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %%
sns.distplot(returns.loc['2015-01-01':'2015-12-31']['MS Return'],bins=100)

# %%
sns.distplot(returns.loc['2015-01-01':'2015-12-31']['C Return'],bins=100)

# %%
sns.distplot(returns.loc['2008-01-01':'2008-12-31']['C Return'],bins=100)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Optional Plotly Method Imports
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df['BAC'].plot(kind='line')

# %%
df.xs('Close',axis=1,level='Stock Info')
# Out:
# Bank Ticker    BAC       C      GS    JPM     MS    WFC
# Date
# 2006-01-03   47.08  492.90  128.87  40.19  58.31  31.90
# 2006-01-04   46.58  483.80  127.09  39.62  58.35  31.53
# 2006-01-05   46.64  486.20  127.04  39.74  58.51  31.50
# 2006-01-06   46.57  486.20  128.84  40.02  58.57  31.68
# 2006-01-09   46.60  483.90  130.39  40.67  59.19  31.68
# ...            ...     ...     ...    ...    ...    ...
# 2015-12-24   17.27   52.71  182.47  66.60  32.48  54.82
# 2015-12-28   17.13   52.38  181.62  66.38  32.17  54.68
# 2015-12-29   17.28   52.98  183.53  67.07  32.55  55.29
# 2015-12-30   17.05   52.30  182.01  66.59  32.23  54.89
# 2015-12-31   16.83   51.75  180.23  66.03  31.81  54.36
#
# [2517 rows x 6 columns]

# %%
close = df.xs('Close',axis=1,level='Stock Info')

# %%
close.plot(figsize=(10,5))

# %%
close['BAC']
# Out:
# Date
# 2006-01-03    47.08
# 2006-01-04    46.58
# 2006-01-05    46.64
# 2006-01-06    46.57
# 2006-01-09    46.60
#               ...
# 2015-12-24    17.27
# 2015-12-28    17.13
# 2015-12-29    17.28
# 2015-12-30    17.05
# 2015-12-31    16.83
# Name: BAC, Length: 2517, dtype: float64

# %%
close['pandas_SMA_3'] = close['BAC'].rolling(window=30).mean()

# %%
close
# Out:
# Bank Ticker    BAC       C      GS    JPM     MS    WFC  pandas_SMA_3
# Date
# 2006-01-03   47.08  492.90  128.87  40.19  58.31  31.90           NaN
# 2006-01-04   46.58  483.80  127.09  39.62  58.35  31.53           NaN
# 2006-01-05   46.64  486.20  127.04  39.74  58.51  31.50           NaN
# 2006-01-06   46.57  486.20  128.84  40.02  58.57  31.68           NaN
# 2006-01-09   46.60  483.90  130.39  40.67  59.19  31.68           NaN
# ...            ...     ...     ...    ...    ...    ...           ...
# 2015-12-24   17.27   52.71  182.47  66.60  32.48  54.82     17.362333
# 2015-12-28   17.13   52.38  181.62  66.38  32.17  54.68     17.354333
# 2015-12-29   17.28   52.98  183.53  67.07  32.55  55.29     17.357000
# 2015-12-30   17.05   52.30  182.01  66.59  32.23  54.89     17.344333
# 2015-12-31   16.83   51.75  180.23  66.03  31.81  54.36     17.324667
#
# [2517 rows x 7 columns]

# %%
close.loc['2008-01-01':'2008-12-31'][['BAC','pandas_SMA_3']].plot(figsize=(10,5))

# %%
sns.heatmap(close[tickers].corr(),annot=True,cmap='coolwarm')

# %%
sns.clustermap(close[tickers].corr(),annot=True,cmap='coolwarm')

# %%
df.loc['2015-01-01':'2016-01-01']['BAC'].iplot(kind='candle')
# Out:
# <div>
#
#
#             <div id="38b57e61-7556-46ba-9857-109ba82ff522" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("38b57e61-7556-46ba-9857-109ba82ff522")) {
#                     Plotly.newPlot(
#                         '38b57e61-7556-46ba-9857-109ba82ff522',
# ...

# %%
df.loc['2015-01-01':'2016-01-01']['MS'].ta_plot(study='sma')
# Out:
# <div>
#
#
#             <div id="1e2a4237-5d96-4389-9a59-15be810d9fd7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("1e2a4237-5d96-4389-9a59-15be810d9fd7")) {
#                     Plotly.newPlot(
#                         '1e2a4237-5d96-4389-9a59-15be810d9fd7',
# ...

# %%
df.loc['2015-01-01':'2016-01-01']['BAC'].ta_plot(study='boll')
# Out:
# <div>
#
#
#             <div id="a07e6da0-734b-443e-af8f-c3d722d09445" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a07e6da0-734b-443e-af8f-c3d722d09445")) {
#                     Plotly.newPlot(
#                         'a07e6da0-734b-443e-af8f-c3d722d09445',
# ...
